# %%
#Importing necessary libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
arr = cv2.imread("cameraman.tif")

# %%
c1 = np.zeros((512,512),np.uint8)

# %%
repetitions = 2
print("\nRepeating arr : \n",np.repeat(arr, repetitions, 1)) 
print("arr Shape : \n", np.repeat(arr, repetitions).shape) 

img = np.repeat(arr, repetitions, 1)

repetitions = 2
print("\nRepeating arr : \n", np.repeat(img, repetitions, 0)) 
print("arr Shape : \n", np.repeat(img, repetitions).shape) 

c2 = np.repeat(img, repetitions, 0)
# Out:
# Repeating arr :
#  [[[156 156 156]
#   [156 156 156]
#   [159 159 159]
#   ...
#   [152 152 152]
#   [152 152 152]
#   [152 152 152]]
#
#  [[160 160 160]
#   [160 160 160]
#   [154 154 154]
#   ...
#   [155 155 155]
#   [153 153 153]
#   [153 153 153]]
#
#  [[156 156 156]
#   [156 156 156]
#   [159 159 159]
#   ...
#   [152 152 152]
#   [152 152 152]
#   [152 152 152]]
#
#  ...
#
#  [[114 114 114]
#   [114 114 114]
#   [132 132 132]
#   ...
#   [137 137 137]
#   [114 114 114]
#   [114 114 114]]
#
#  [[121 121 121]
#   [121 121 121]
#   [126 126 126]
#   ...
#   [130 130 130]
#   [113 113 113]
#   [113 113 113]]
#
#  [[121 121 121]
#   [121 121 121]
#   [126 126 126]
#   ...
#   [130 130 130]
#   [113 113 113]
#   [113 113 113]]]
# arr Shape :
#  (393216,)
#
# Repeating arr :
#  [[[156 156 156]
#   [156 156 156]
#   [159 159 159]
#   ...
#   [152 152 152]
#   [152 152 152]
#   [152 152 152]]
#
#  [[156 156 156]
#   [156 156 156]
#   [159 159 159]
#   ...
#   [152 152 152]
# ...

# %%
plt.imshow(c2,cmap = 'gray')
